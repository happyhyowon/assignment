# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import time
import cv2
import numpy as np
from corners import *
import random

# %%
def loadImages():
    images = []
    for i in range(1,11):
        location = r"imgs/%d.jpg"%i
        img = rgb2gray(mpl.image.imread(location))
        images.append(img)
    return images

# %%
def getFeaturePoints(img, winSize=21):
    result = cornerDetect(img, winSize, k=0.04, thd=1e14, type=1)
    # Non maximum suppression
    tempScale = np.pad(result, 2, mode='constant')
    width, height = tempScale.shape
    for x in range(2, width-2):
        for y in range(2, height-2):
            if tempScale[x][y] != np.max(tempScale[x-2:x+3, y-2:y+3]):
                tempScale[x][y] = 0
    result = tempScale[2:width-2, 2:height-2]
    y, x = np.nonzero(result)
    print('Number of corner : %d'%y.shape)
    return x,y

# %%
def getFeatureDescriptors(X, Y, winSize, img):
    neighbors = []
    descriptors = []
    newPoint = []
    for x, y in zip(X,Y):
        patch_center = np.array([x, y])
        image = np.array(img)
        patch_size = winSize
        patch_x = int(patch_center[1] - patch_size / 2.)
        patch_y = int(patch_center[0] - patch_size / 2.)
        if patch_x < 0 or patch_y < 0:
            #print('!')
            continue
        else:
            patch_image = image[patch_x:patch_x+patch_size, patch_y:patch_y+patch_size]
            #patch_image = np.float32(patch_image)/255.0
            patch_image = patch_image.astype(np.uint8)
            neighbors.append(patch_image.flatten())
            newPoint.append([x,y])
    return np.array(newPoint), np.array(neighbors)

# %%
def match2Images(desc1, keypoint1, desc2, keypoint2, type='ncc', th = 2):
    dist = []
    keypoints = []
    
    for des1, key1 in zip(desc1, keypoint1):
        for des2, key2 in zip(desc2, keypoint2):
            if type == 'ncc':
                des1Norm = des1 / np.sqrt((np.sum(des1**2)))
                des2Norm = des2 / np.sqrt((np.sum(des2**2)))
                distance = np.dot(des1Norm.T,des2Norm)
                dist.append(distance)
                keypoints.append((key1, key2))
            elif type == 'euclidean':
                dist.append(np.sqrt(np.sum((des1-des2)**2)))
                keypoints.append((key1, key2))
            else:
                print('type error : use [ncc] or [euclidean]')
                
    dist = np.array(dist)
    keypoints = np.array(keypoints)
    if type == 'ncc':
        print('#ncc# min : %0.0f, max : %0.0f'%(min(dist),max(dist)))
        temp = dist < th
        idxOfCorrectMatching = np.nonzero(temp)
    elif type == 'euclidean':
        print('#euclidean#  min : %0.0f, max : %0.0f'%(min(dist),max(dist)))
        temp = dist < th
        idxOfCorrectMatching = np.nonzero(temp)
    else:
        print('type error : use [ncc] or [euclidean]')
    candidateCorrespondences = []
    for i in idxOfCorrectMatching:
        candidateCorrespondences.append(keypoints[i])
    return np.array(candidateCorrespondences).reshape(len(candidateCorrespondences[0]),2,2)

# %%
def refineMatches(feature_points, match_list):
# Out:
#   File "<ipython-input-6-bbdcf7edc8fc>", line 2
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# 그레이스케일된 이미지를 불러온다. 리스트로 10장

# %%
images = loadImages()

# %% [markdown]
# 각 이미지의 코너를 DETECT한다.
# 이미지 마다 DETECT된 코너좌표를 리스트로 저장 imgX[0~9], imgY[0~9]
# # 10장 다 해야해서 오래걸림;;

# %%
imgX = []
imgY = []
fig = plt.figure(figsize=(15,8))
for i in range(10):
    X,Y = getFeaturePoints(images[i], 40)
    imgX.append(X)
    imgY.append(Y)
    ax = fig.add_subplot(2,5,i+1)
    ax.imshow(images[i], cmap='gray')
    ax.scatter(imgX[i], imgY[i], 50, marker='x', alpha = 0.3,color='r')
    ax.axis('off')
plt.show()
# Out:
# Number of corner : 2474
# Number of corner : 2405
# Number of corner : 2816
# Number of corner : 1684
# Number of corner : 2575
# Number of corner : 1349
# Number of corner : 2265
# Number of corner : 1866
# Number of corner : 1456
# Number of corner : 1989

# %%
fig = plt.figure()
X,Y = getFeaturePoints(images[i],40)
plt.imshow(images[i], cmap='gray')
plt.scatter(X, Y, 50, marker='x', alpha = 0.3,color='r')
plt.axis('off')
plt.show()
# Out:
# Number of corner : 1989

# %% [markdown]
# test로 첫번째 두번째 이미지의 flatten된 feature를 뽑는다.

# %%
keypoint1, desc1 = getFeatureDescriptors(imgX[0], imgY[0], 5, images[0])

# %%
keypoint2, desc2 = getFeatureDescriptors(imgX[1], imgY[1], 5, images[1])

# %% [markdown]
# feature사이에 거리를 기준으로 일정 쓰레시홀드 안에 들어오는 쌍들을 찾는다.

# %%
candidate = match2Images(desc1,keypoint1,desc2,keypoint2,'ncc')
print('find %d matches'%len(candidate))
# Out:
# #ncc# min : 1, max : 844
# find 143 matches

# %% [markdown]
# 매칭쌍들의 좌표를 스플릿하여 저장

# %%
img1X_candi = candidate[:,:1,:1].reshape(len(candidate))
img1Y_candi = candidate[:,:1,1:].reshape(len(candidate))
img2X_candi = candidate[:,1:,:1].reshape(len(candidate))
img2Y_candi = candidate[:,1:,1:].reshape(len(candidate))

# %% [markdown]
# 각각의 이미지에 매칭쌍 좌표 출력

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)
ax1.imshow(images[0], cmap='gray')
ax1.scatter(img1X_candi, img1Y_candi, marker='x', alpha = 0.7,color='r')
ax1.axis('off')
ax2.imshow(images[1], cmap='gray')
ax2.scatter(img2X_candi, img2Y_candi, marker='x', alpha = 0.7,color='r')
ax2.axis('off')
plt.show()

# %% [markdown]
# 아홉번째와 열번째 이미지 도 마찬가지로 테스트

# %%
keypoint8, desc8 = getFeatureDescriptors(imgX[2], imgY[2], 30, images[2])
keypoint9, desc9 = getFeatureDescriptors(imgX[3], imgY[3], 30, images[3])

# %%
candidate = match2Images(desc8,keypoint8,desc9,keypoint9,'euclidean', 160)
print('find %d matches'%len(candidate))
# Out:
# #euclidean#  min : 114, max : 344
# find 32 matches

# %%
img1X_candi = candidate[:,:1,:1].reshape(len(candidate))
img1Y_candi = candidate[:,:1,1:].reshape(len(candidate))
img2X_candi = candidate[:,1:,:1].reshape(len(candidate))
img2Y_candi = candidate[:,1:,1:].reshape(len(candidate))

fig = plt.figure()
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)
ax1.imshow(images[2], cmap='gray')
ax2.imshow(images[3], cmap='gray')
for x1, y1, x2, y2 in zip(img1X_candi, img1Y_candi, img2X_candi, img2Y_candi):
    ax1.scatter(x1, y1, marker='x')
    ax2.scatter(x2, y2, marker='x')
ax1.axis('off')
ax2.axis('off')
plt.show()

# %% [markdown]
# test

# %%
def calculateHomography(correspondences):
    #loop through correspondences and create assemble matrix
    aList = []
    for corr in correspondences:
        p1 = np.matrix([corr.item(0), corr.item(1), 1])
        p2 = np.matrix([corr.item(2), corr.item(3), 1])

        a2 = [0, 0, 0, -p2.item(2) * p1.item(0), -p2.item(2) * p1.item(1), -p2.item(2) * p1.item(2),
              p2.item(1) * p1.item(0), p2.item(1) * p1.item(1), p2.item(1) * p1.item(2)]
        a1 = [-p2.item(2) * p1.item(0), -p2.item(2) * p1.item(1), -p2.item(2) * p1.item(2), 0, 0, 0,
              p2.item(0) * p1.item(0), p2.item(0) * p1.item(1), p2.item(0) * p1.item(2)]
        aList.append(a1)
        aList.append(a2)

    matrixA = np.matrix(aList)

    #svd composition
    u, s, v = np.linalg.svd(matrixA)

    #reshape the min singular value into a 3 by 3 matrix
    h = np.reshape(v[8], (3, 3))

    #normalize and now we have h
    h = (1/h.item(8)) * h
    return h

# %%
def geometricDistance(correspondence, h):

    p1 = np.transpose(np.matrix([correspondence[0].item(0), correspondence[0].item(1), 1]))
    estimatep2 = np.dot(h, p1)
    estimatep2 = (1/(estimatep2.item(2) + 1e-8))*estimatep2

    p2 = np.transpose(np.matrix([correspondence[0].item(2), correspondence[0].item(3), 1]))
    error = p2 - estimatep2
    return np.linalg.norm(error)

# %%
def ransac(corr, thresh):
    maxInliers = []
    min_residual = -99999
    finalH = None
    for i in range(1000):
        #find 4 random points to calculate a homography
        corr1 = corr[random.randrange(0, len(corr))]
        corr2 = corr[random.randrange(0, len(corr))]
        randomFour = np.vstack((corr1, corr2))
        corr3 = corr[random.randrange(0, len(corr))]
        randomFour = np.vstack((randomFour, corr3))
        corr4 = corr[random.randrange(0, len(corr))]
        randomFour = np.vstack((randomFour, corr4))

        #call the homography function on those points
        h = calculateHomography(randomFour)
        inliers = []
        
        residual = 0
        for i in range(len(corr)):
            d = geometricDistance(corr[i], h)
            residual = residual + d
            if d < thresh:
                inliers.append(corr[i])
            
        avg_residual = residual / len(corr)

        if len(inliers) > len(maxInliers):
            finalH = h
            maxInliers = inliers
            
        print("step: ", i, " average residual: ", avg_residual, " NumInliers: ", len(inliers))
        
    return finalH, maxInliers

# %%
correspondenceList = []
for x1, y1, x2, y2 in zip(img1X_candi, img1Y_candi, img2X_candi, img2Y_candi):
        correspondenceList.append([x1, y1, x2, y2])
corrs = np.matrix(correspondenceList)
inlier_thresh = 10
finalH, inliers = ransac(corrs, inlier_thresh)
# Out:
# step:  31  average residual:  22.757743093192246  NumInliers:  15
# step:  31  average residual:  123.91229775940982  NumInliers:  10
# step:  31  average residual:  39.25314435327175  NumInliers:  18
# step:  31  average residual:  181.13396614533795  NumInliers:  7
# step:  31  average residual:  70.40982776549255  NumInliers:  11
# step:  31  average residual:  68.8428268614862  NumInliers:  20
# step:  31  average residual:  119.30443576404858  NumInliers:  19
# step:  31  average residual:  155.7225555136474  NumInliers:  8
# step:  31  average residual:  132.37517621051902  NumInliers:  9
# step:  31  average residual:  82.92598215109142  NumInliers:  8
# step:  31  average residual:  365.4949946641554  NumInliers:  6
# step:  31  average residual:  36.63975760494286  NumInliers:  19
# step:  31  average residual:  30.233098288514878  NumInliers:  17
# step:  31  average residual:  74.29584631068334  NumInliers:  9
# step:  31  average residual:  72.10335007709601  NumInliers:  14
# step:  31  average residual:  604.2697223560849  NumInliers:  2
# step:  31  average residual:  257.96621206505364  NumInliers:  5
# step:  31  average residual:  16.774890013785928  NumInliers:  27
# step:  31  average residual:  62.32412003301922  NumInliers:  13
# step:  31  average residual:  62.39462472501309  NumInliers:  14
# step:  31  average residual:  153.0345090570068  NumInliers:  18
# step:  31  average residual:  93.19885392350469  NumInliers:  12
# step:  31  average residual:  93.21708285100837  NumInliers:  15
# step:  31  average residual:  15.760194271711944  NumInliers:  22
# step:  31  average residual:  32.87466853169874  NumInliers:  19
# step:  31  average residual:  1982.521028780146  NumInliers:  5
# step:  31  average residual:  59.21223219764984  NumInliers:  12
# step:  31  average residual:  121.3431708188686  NumInliers:  23
# step:  31  average residual:  27.401309031565265  NumInliers:  25
# step:  31  average residual:  526.0699967918213  NumInliers:  2
# step:  31  average residual:  234.78349963813486  NumInliers:  4
# step:  31  average residual:  293.02579481331793  NumInliers:  4
# step:  31  average residual:  113.82557980079514  NumInliers:  7
# step:  31  average residual:  74.49987442152299  NumInliers:  6
# step:  31  average residual:  492.81205747720117  NumInliers:  2
# step:  31  average residual:  58.12633710941258  NumInliers:  15
# step:  31  average residual:  63.619759085520975  NumInliers:  3
# step:  31  average residual:  72.91063737476671  NumInliers:  11
# step:  31  average residual:  115.46208832260933  NumInliers:  3
# step:  31  average residual:  64.87725808256035  NumInliers:  14
# step:  31  average residual:  199.89231628170128  NumInliers:  7
# step:  31  average residual:  12.450302748865145  NumInliers:  27
# step:  31  average residual:  694.3205897442095  NumInliers:  5
# step:  31  average residual:  11.194418823941993  NumInliers:  23
# step:  31  average residual:  164.70428206569963  NumInliers:  5
# step:  31  average residual:  437.17556709296457  NumInliers:  2
# step:  31  average residual:  64.16207089990618  NumInliers:  17
# step:  31  average residual:  58.71267666717348  NumInliers:  11
# step:  31  average residual:  108.127025593017  NumInliers:  14
# step:  31  average residual:  66.25354273422234  NumInliers:  5
# step:  31  average residual:  108.09828189844984  NumInliers:  5
# step:  31  average residual:  806.3067406008785  NumInliers:  2
# step:  31  average residual:  171.35614678498303  NumInliers:  7
# step:  31  average residual:  136.88344033992195  NumInliers:  3
# step:  31  average residual:  18.64782298690697  NumInliers:  26
# step:  31  average residual:  98.86110283946665  NumInliers:  10
# step:  31  average residual:  70.34113747818532  NumInliers:  13
# step:  31  average residual:  89.38933017791732  NumInliers:  7
# step:  31  average residual:  259.209439318381  NumInliers:  6
# step:  31  average residual:  148.78806473091936  NumInliers:  7
# step:  31  average residual:  110.73537432332711  NumInliers:  10
# step:  31  average residual:  29.83911247379503  NumInliers:  14
# step:  31  average residual:  50.705950200399634  NumInliers:  16
# step:  31  average residual:  18.272921776860784  NumInliers:  23
# step:  31  average residual:  68.03768464901945  NumInliers:  10
# step:  31  average residual:  24.244058122221084  NumInliers:  14
# step:  31  average residual:  749.3081082670249  NumInliers:  18
# step:  31  average residual:  39.99623818297792  NumInliers:  14
# step:  31  average residual:  75.9438016541105  NumInliers:  7
# step:  31  average residual:  21.523394113416465  NumInliers:  26
# step:  31  average residual:  1090.5715242751676  NumInliers:  2
# step:  31  average residual:  471.30798269993386  NumInliers:  6
# step:  31  average residual:  101.55914425069616  NumInliers:  12
# step:  31  average residual:  60.27448777530293  NumInliers:  7
# step:  31  average residual:  15.168123436642984  NumInliers:  22
# step:  31  average residual:  32.819031911501305  NumInliers:  17
# step:  31  average residual:  171.96974270276274  NumInliers:  2
# step:  31  average residual:  10.968636846612345  NumInliers:  26
# step:  31  average residual:  74.60620568934343  NumInliers:  11
# step:  31  average residual:  115.25848116721926  NumInliers:  10
# step:  31  average residual:  624.0656009922936  NumInliers:  2
# step:  31  average residual:  84.84241149448293  NumInliers:  10
# step:  31  average residual:  210.38899479071043  NumInliers:  3
# step:  31  average residual:  174.80475632339014  NumInliers:  6
# step:  31  average residual:  85.22747486535069  NumInliers:  7
# step:  31  average residual:  250.16893191214405  NumInliers:  6
# step:  31  average residual:  277.9500264197331  NumInliers:  3
# step:  31  average residual:  330.8258610274077  NumInliers:  3
# step:  31  average residual:  176.16708562267172  NumInliers:  8
# step:  31  average residual:  152.37433428513623  NumInliers:  17
# step:  31  average residual:  14.583900848347776  NumInliers:  23
# step:  31  average residual:  20.88356536841694  NumInliers:  20
# step:  31  average residual:  75.24180604614835  NumInliers:  8
# step:  31  average residual:  95.46893064286981  NumInliers:  12
# step:  31  average residual:  75.52460285166909  NumInliers:  8
# step:  31  average residual:  290.11838291262546  NumInliers:  3
# step:  31  average residual:  30.80400379156947  NumInliers:  17
# step:  31  average residual:  3402.9277966427626  NumInliers:  9
# step:  31  average residual:  686.1508581616469  NumInliers:  1
# step:  31  average residual:  137.20134401953715  NumInliers:  8
# step:  31  average residual:  20.72751218879539  NumInliers:  26
# step:  31  average residual:  300.97725623327983  NumInliers:  11
# step:  31  average residual:  273.1030698751403  NumInliers:  19
# step:  31  average residual:  193.42168669676326  NumInliers:  10
# step:  31  average residual:  80.65471309195597  NumInliers:  19
# step:  31  average residual:  56.48109429814227  NumInliers:  18
# step:  31  average residual:  70.05499876909893  NumInliers:  14
# step:  31  average residual:  554.2738220306485  NumInliers:  4
# step:  31  average residual:  132.57050860962354  NumInliers:  8
# step:  31  average residual:  122.85414619186051  NumInliers:  3
# step:  31  average residual:  46.53355728555307  NumInliers:  20
# step:  31  average residual:  43.909286565804045  NumInliers:  15
# step:  31  average residual:  70.96709628976372  NumInliers:  11
# step:  31  average residual:  111.79236973489378  NumInliers:  7
# step:  31  average residual:  73.38231833418129  NumInliers:  11
# step:  31  average residual:  36.068137582592584  NumInliers:  8
# step:  31  average residual:  12.11350954222689  NumInliers:  27
# step:  31  average residual:  178.73858822466767  NumInliers:  4
# step:  31  average residual:  86.10576606064586  NumInliers:  13
# step:  31  average residual:  136.95022428280618  NumInliers:  8
# step:  31  average residual:  172.13443951280956  NumInliers:  6
# step:  31  average residual:  137.1071103782954  NumInliers:  3
# step:  31  average residual:  62.65242742322631  NumInliers:  15
# step:  31  average residual:  122.49024414638762  NumInliers:  14
# step:  31  average residual:  18.118134186756034  NumInliers:  23
# step:  31  average residual:  168.1940345768333  NumInliers:  4
# step:  31  average residual:  11457.929129520038  NumInliers:  3
# step:  31  average residual:  133.4150680806125  NumInliers:  2
# step:  31  average residual:  14.653435603591298  NumInliers:  22
# step:  31  average residual:  105.11644572630053  NumInliers:  10
# step:  31  average residual:  595.9205686103184  NumInliers:  5
# step:  31  average residual:  24.674684542276008  NumInliers:  23
# step:  31  average residual:  155.52081066824275  NumInliers:  4
# step:  31  average residual:  97.71384753106902  NumInliers:  12
# step:  31  average residual:  82.93311853760706  NumInliers:  10
# step:  31  average residual:  570.960284956206  NumInliers:  4
# step:  31  average residual:  115.97542603464875  NumInliers:  15
# step:  31  average residual:  83.25929070416751  NumInliers:  11
# step:  31  average residual:  149.0745398615319  NumInliers:  17
# step:  31  average residual:  137.61489644304635  NumInliers:  11
# step:  31  average residual:  14.694496566353173  NumInliers:  23
# step:  31  average residual:  11.728369801365645  NumInliers:  26
# step:  31  average residual:  113.71196572239867  NumInliers:  10
# step:  31  average residual:  100.71399998650186  NumInliers:  12
# step:  31  average residual:  1332.9683073450678  NumInliers:  6
# step:  31  average residual:  207.09538416380016  NumInliers:  4
# step:  31  average residual:  439.8126717320448  NumInliers:  3
# step:  31  average residual:  13.500007929979004  NumInliers:  22
# step:  31  average residual:  152.3715772645882  NumInliers:  7
# step:  31  average residual:  19.457596957800153  NumInliers:  16
# step:  31  average residual:  109.6049737908167  NumInliers:  7
# step:  31  average residual:  149.76321940778547  NumInliers:  15
# step:  31  average residual:  60.39652891597532  NumInliers:  16
# step:  31  average residual:  10.699484615017857  NumInliers:  24
# step:  31  average residual:  1446.1120996084771  NumInliers:  3
# step:  31  average residual:  157.3645766502177  NumInliers:  8
# step:  31  average residual:  55.11287265974927  NumInliers:  12
# step:  31  average residual:  101.95610498839615  NumInliers:  10
# step:  31  average residual:  84.82383733410512  NumInliers:  16
# step:  31  average residual:  69.34010732527004  NumInliers:  9
# step:  31  average residual:  641.8778694469025  NumInliers:  1
# step:  31  average residual:  58.38467809880065  NumInliers:  16
# step:  31  average residual:  2159.209290806295  NumInliers:  8
# step:  31  average residual:  60.924310181257134  NumInliers:  21
# step:  31  average residual:  158.0905397724824  NumInliers:  3
# step:  31  average residual:  569.8172519893586  NumInliers:  6
# step:  31  average residual:  139.74021758916518  NumInliers:  3
# step:  31  average residual:  10.727706054772828  NumInliers:  26
# step:  31  average residual:  92.53252791821754  NumInliers:  5
# step:  31  average residual:  105.89390510446783  NumInliers:  5
# step:  31  average residual:  70.85333060233103  NumInliers:  12
# step:  31  average residual:  42.19186013188263  NumInliers:  21
# step:  31  average residual:  82.53101494804659  NumInliers:  6
# step:  31  average residual:  142.73791119766855  NumInliers:  3
# step:  31  average residual:  481.4454882275871  NumInliers:  3
# step:  31  average residual:  355.67477119493583  NumInliers:  12
# step:  31  average residual:  139.40612036235942  NumInliers:  5
# step:  31  average residual:  23.453987910152197  NumInliers:  19
# step:  31  average residual:  35.622667619633944  NumInliers:  16
# step:  31  average residual:  63.741260402030164  NumInliers:  14
# step:  31  average residual:  75.06043279014041  NumInliers:  10
# step:  31  average residual:  35.72096828401829  NumInliers:  20
# step:  31  average residual:  471.6629952593781  NumInliers:  14
# step:  31  average residual:  71.24800164260714  NumInliers:  11
# step:  31  average residual:  73.56769552558912  NumInliers:  10
# step:  31  average residual:  32.59575477308563  NumInliers:  20
# step:  31  average residual:  298.96299438755295  NumInliers:  5
# step:  31  average residual:  18.111119362538783  NumInliers:  26
# step:  31  average residual:  149.1104787575462  NumInliers:  3
# step:  31  average residual:  157.80674329042927  NumInliers:  16
# step:  31  average residual:  15.989007947370272  NumInliers:  27
# step:  31  average residual:  120.50058029412939  NumInliers:  23
# step:  31  average residual:  138.13349049069782  NumInliers:  12
# step:  31  average residual:  927.5697262805573  NumInliers:  4
# step:  31  average residual:  40.82699900008909  NumInliers:  16
# step:  31  average residual:  139.52606616808333  NumInliers:  9
# step:  31  average residual:  254.35097728911  NumInliers:  4
# step:  31  average residual:  116.71143038254239  NumInliers:  3
# step:  31  average residual:  931.9354925272548  NumInliers:  8
# step:  31  average residual:  467.84173338699566  NumInliers:  3
# step:  31  average residual:  55.4751568649266  NumInliers:  13
# step:  31  average residual:  14.994954591110547  NumInliers:  20
# step:  31  average residual:  39.28315755464589  NumInliers:  20
# step:  31  average residual:  86.54963005655557  NumInliers:  5
# step:  31  average residual:  623.0007256256963  NumInliers:  7
# step:  31  average residual:  174.30459745426953  NumInliers:  14
# step:  31  average residual:  99.80794822288631  NumInliers:  7
# step:  31  average residual:  111.80769490967629  NumInliers:  10
# step:  31  average residual:  161.52354129267775  NumInliers:  16
# step:  31  average residual:  64.28783612907698  NumInliers:  5
# step:  31  average residual:  21.201926511433317  NumInliers:  18
# step:  31  average residual:  141.05859449737147  NumInliers:  9
# step:  31  average residual:  22.325307551157117  NumInliers:  26
# step:  31  average residual:  484.11645540438667  NumInliers:  3
# step:  31  average residual:  258.8266726062442  NumInliers:  10
# step:  31  average residual:  65.91439294203425  NumInliers:  17
# step:  31  average residual:  92.0721082236116  NumInliers:  7
# step:  31  average residual:  43.583952797113  NumInliers:  6
# step:  31  average residual:  75.44160272336802  NumInliers:  12
# step:  31  average residual:  51.845262949951746  NumInliers:  16
# step:  31  average residual:  43.63270024269556  NumInliers:  6
# step:  31  average residual:  27.608597449497807  NumInliers:  14
# step:  31  average residual:  10.81043005401626  NumInliers:  25
# step:  31  average residual:  103.79475743428098  NumInliers:  3
# step:  31  average residual:  205.27855874544173  NumInliers:  12
# step:  31  average residual:  110.54271902840776  NumInliers:  8
# step:  31  average residual:  192.53900800167602  NumInliers:  5
# step:  31  average residual:  39.72540669181458  NumInliers:  15
# step:  31  average residual:  289.3900513800944  NumInliers:  5
# step:  31  average residual:  27.60977939038387  NumInliers:  15
# step:  31  average residual:  120.51197245355326  NumInliers:  10
# step:  31  average residual:  94.82873846660169  NumInliers:  10
# step:  31  average residual:  33.11313277193283  NumInliers:  8
# step:  31  average residual:  114.69936343442355  NumInliers:  10
# step:  31  average residual:  79.07398101461487  NumInliers:  6
# step:  31  average residual:  44.778880807010935  NumInliers:  13
# step:  31  average residual:  10.97993507135708  NumInliers:  26
# step:  31  average residual:  18.33507188053401  NumInliers:  20
# step:  31  average residual:  14.002744768756637  NumInliers:  27
# step:  31  average residual:  60.84282813427564  NumInliers:  13
# step:  31  average residual:  283.39040390522257  NumInliers:  3
# step:  31  average residual:  145.09969662461504  NumInliers:  3
# step:  31  average residual:  91.86440230336265  NumInliers:  5
# step:  31  average residual:  93.90866720561246  NumInliers:  11
# step:  31  average residual:  134.8160694549675  NumInliers:  3
# step:  31  average residual:  34.50157743484108  NumInliers:  23
# step:  31  average residual:  122.18506883565676  NumInliers:  3
# step:  31  average residual:  104.70873641183692  NumInliers:  16
# step:  31  average residual:  20.43367659135179  NumInliers:  20
# step:  31  average residual:  27.028593121034888  NumInliers:  15
# step:  31  average residual:  22.815338199439523  NumInliers:  20
# step:  31  average residual:  17.74316752373452  NumInliers:  26
# step:  31  average residual:  381.3528623812173  NumInliers:  3
# step:  31  average residual:  15.620534111742629  NumInliers:  23
# step:  31  average residual:  236.71440718127144  NumInliers:  4
# step:  31  average residual:  10.037309867567492  NumInliers:  24
# step:  31  average residual:  13.198518715169055  NumInliers:  20
# step:  31  average residual:  56.5870841906653  NumInliers:  14
# step:  31  average residual:  513.1979709783653  NumInliers:  14
# step:  31  average residual:  35.15290808838673  NumInliers:  17
# step:  31  average residual:  106.70668749435265  NumInliers:  10
# step:  31  average residual:  172.27042458686606  NumInliers:  3
# step:  31  average residual:  37.915553590887285  NumInliers:  15
# step:  31  average residual:  295.7912034694564  NumInliers:  20
# step:  31  average residual:  275.2014010913202  NumInliers:  6
# step:  31  average residual:  13.191295673167415  NumInliers:  25
# step:  31  average residual:  131.01021006008946  NumInliers:  5
# step:  31  average residual:  137.39977267677497  NumInliers:  4
# step:  31  average residual:  63.116449635437846  NumInliers:  9
# step:  31  average residual:  133.30854724985466  NumInliers:  4
# step:  31  average residual:  13702.963768759078  NumInliers:  2
# step:  31  average residual:  170.56101752848272  NumInliers:  12
# step:  31  average residual:  24.69990013225219  NumInliers:  11
# step:  31  average residual:  33.43455992255746  NumInliers:  25
# step:  31  average residual:  673.7077737925292  NumInliers:  19
# step:  31  average residual:  636.0407829054932  NumInliers:  1
# step:  31  average residual:  62.31505779245322  NumInliers:  11
# step:  31  average residual:  15.831822903468138  NumInliers:  18
# step:  31  average residual:  35.92661438376332  NumInliers:  25
# step:  31  average residual:  13.508314137163364  NumInliers:  21
# step:  31  average residual:  11.969689758829789  NumInliers:  26
# step:  31  average residual:  181.07728648289535  NumInliers:  4
# step:  31  average residual:  105.5020163047581  NumInliers:  9
# step:  31  average residual:  264.3126633300385  NumInliers:  5
# step:  31  average residual:  180.03646321986628  NumInliers:  4
# step:  31  average residual:  18.239273125419924  NumInliers:  26
# step:  31  average residual:  84.16356668424551  NumInliers:  17
# step:  31  average residual:  116.8339082410075  NumInliers:  15
# step:  31  average residual:  86.65310924183933  NumInliers:  5
# step:  31  average residual:  24.836611036071044  NumInliers:  9
# step:  31  average residual:  375.4742722350433  NumInliers:  3
# step:  31  average residual:  403.72415129504225  NumInliers:  2
# step:  31  average residual:  197.41220868992167  NumInliers:  3
# step:  31  average residual:  303.98480075961055  NumInliers:  3
# step:  31  average residual:  29.932971498814858  NumInliers:  22
# step:  31  average residual:  80.45927269553563  NumInliers:  7
# step:  31  average residual:  221.58919112430368  NumInliers:  17
# step:  31  average residual:  70.96511769940919  NumInliers:  11
# step:  31  average residual:  826.3261888456769  NumInliers:  4
# step:  31  average residual:  146.43902083826285  NumInliers:  2
# step:  31  average residual:  161.22224181890138  NumInliers:  3
# step:  31  average residual:  620.5670265361647  NumInliers:  8
# step:  31  average residual:  67.97195852604922  NumInliers:  13
# step:  31  average residual:  84.89670780767734  NumInliers:  8
# step:  31  average residual:  14.425295554557591  NumInliers:  27
# step:  31  average residual:  20.246670775256398  NumInliers:  26
# step:  31  average residual:  97.43988027529436  NumInliers:  10
# step:  31  average residual:  142.65538326471466  NumInliers:  3
# step:  31  average residual:  136.06535579284153  NumInliers:  8
# step:  31  average residual:  16.590189185674134  NumInliers:  17
# step:  31  average residual:  27.62364826499988  NumInliers:  17
# step:  31  average residual:  51.066744568550654  NumInliers:  18
# step:  31  average residual:  65.59251844405529  NumInliers:  8
# step:  31  average residual:  33.55303471225488  NumInliers:  18
# step:  31  average residual:  107.47570168756533  NumInliers:  12
# step:  31  average residual:  110.1117394101309  NumInliers:  10
# step:  31  average residual:  178.66752686365768  NumInliers:  7
# step:  31  average residual:  11.128600166087123  NumInliers:  23
# step:  31  average residual:  370.8031150163104  NumInliers:  6
# step:  31  average residual:  305.04735968621884  NumInliers:  4
# step:  31  average residual:  23.0465433676489  NumInliers:  18
# step:  31  average residual:  27.959808913057213  NumInliers:  25
# step:  31  average residual:  17.53945806130148  NumInliers:  20
# step:  31  average residual:  40.846110923746465  NumInliers:  17
# step:  31  average residual:  76.10702130206629  NumInliers:  9
# step:  31  average residual:  1544.0922464750242  NumInliers:  7
# step:  31  average residual:  1165.3262583592355  NumInliers:  4
# step:  31  average residual:  1698.2097574113375  NumInliers:  14
# step:  31  average residual:  14.05393957690417  NumInliers:  19
# step:  31  average residual:  28.05999587012473  NumInliers:  7
# step:  31  average residual:  12.614648752615764  NumInliers:  27
# step:  31  average residual:  86.96889598236217  NumInliers:  20
# step:  31  average residual:  110.31605966427864  NumInliers:  10
# step:  31  average residual:  115.49577158766684  NumInliers:  10
# step:  31  average residual:  269.95752461520044  NumInliers:  3
# step:  31  average residual:  111.44138422174579  NumInliers:  10
# step:  31  average residual:  240.25831878125342  NumInliers:  6
# step:  31  average residual:  157.39760961008201  NumInliers:  6
# step:  31  average residual:  424.0401176977744  NumInliers:  16
# step:  31  average residual:  13.650061455497324  NumInliers:  27
# step:  31  average residual:  14.20324723450726  NumInliers:  27
# step:  31  average residual:  81.61788798268113  NumInliers:  11
# step:  31  average residual:  725.4490915906929  NumInliers:  5
# step:  31  average residual:  17.358813433749074  NumInliers:  23
# step:  31  average residual:  181.92982726610532  NumInliers:  7
# step:  31  average residual:  27.53861761554348  NumInliers:  18
# step:  31  average residual:  150.34480767235428  NumInliers:  11
# step:  31  average residual:  202.42901422481975  NumInliers:  4
# step:  31  average residual:  167.85684885095895  NumInliers:  7
# step:  31  average residual:  305.17964912309816  NumInliers:  5
# step:  31  average residual:  73.70261889589202  NumInliers:  8
# step:  31  average residual:  11.953886607838653  NumInliers:  24
# step:  31  average residual:  10.076468239796641  NumInliers:  26
# step:  31  average residual:  51.9160971136141  NumInliers:  14
# step:  31  average residual:  82.2808419576253  NumInliers:  13
# step:  31  average residual:  195.29420751202764  NumInliers:  6
# step:  31  average residual:  136.3781449975395  NumInliers:  7
# step:  31  average residual:  144.7791680618193  NumInliers:  18
# step:  31  average residual:  86.43379281472066  NumInliers:  19
# step:  31  average residual:  23.299864143903612  NumInliers:  17
# step:  31  average residual:  87.59633799910846  NumInliers:  7
# step:  31  average residual:  65.09462475359373  NumInliers:  18
# step:  31  average residual:  65.93498402382869  NumInliers:  14
# step:  31  average residual:  118.7387738404927  NumInliers:  14
# step:  31  average residual:  204.41056385470696  NumInliers:  12
# step:  31  average residual:  12.070546727631882  NumInliers:  26
# step:  31  average residual:  606.2824007009597  NumInliers:  2
# step:  31  average residual:  89.67229647525326  NumInliers:  4
# step:  31  average residual:  75.12865667648354  NumInliers:  13
# step:  31  average residual:  134.1487330589528  NumInliers:  8
# step:  31  average residual:  21.303253774280147  NumInliers:  20
# step:  31  average residual:  78.92679236708676  NumInliers:  15
# step:  31  average residual:  77.7067117711991  NumInliers:  15
# step:  31  average residual:  195.75986630879225  NumInliers:  6
# step:  31  average residual:  97.32204632264263  NumInliers:  14
# step:  31  average residual:  137.07657262206254  NumInliers:  3
# step:  31  average residual:  11.504380189435302  NumInliers:  26
# step:  31  average residual:  77.87030664172043  NumInliers:  17
# step:  31  average residual:  693.9381258552039  NumInliers:  0
# step:  31  average residual:  22.12474999821428  NumInliers:  21
# step:  31  average residual:  94.46158675500654  NumInliers:  9
# step:  31  average residual:  96.70154713548416  NumInliers:  9
# step:  31  average residual:  142.01426332386518  NumInliers:  5
# step:  31  average residual:  73.36883612863208  NumInliers:  13
# step:  31  average residual:  77.34569723421352  NumInliers:  13
# step:  31  average residual:  140.76369573837047  NumInliers:  3
# step:  31  average residual:  11.276377775266814  NumInliers:  27
# step:  31  average residual:  460.66159464667356  NumInliers:  2
# step:  31  average residual:  121.97858447933359  NumInliers:  3
# step:  31  average residual:  183.61459671326233  NumInliers:  4
# step:  31  average residual:  113.90270222746224  NumInliers:  17
# step:  31  average residual:  55.91493787340297  NumInliers:  15
# step:  31  average residual:  70.75986174409678  NumInliers:  9
# step:  31  average residual:  65.82566844789754  NumInliers:  11
# step:  31  average residual:  88.3268404368487  NumInliers:  7
# step:  31  average residual:  102.21307525490613  NumInliers:  10
# step:  31  average residual:  103.43035295459823  NumInliers:  8
# step:  31  average residual:  10.803780626380869  NumInliers:  24
# step:  31  average residual:  195.49772162714999  NumInliers:  12
# step:  31  average residual:  40.263901268647274  NumInliers:  17
# step:  31  average residual:  83.46615733281043  NumInliers:  6
# step:  31  average residual:  91.28547706555942  NumInliers:  6
# step:  31  average residual:  104.95888468036456  NumInliers:  10
# step:  31  average residual:  158.25811106352205  NumInliers:  23
# step:  31  average residual:  228.00396652404066  NumInliers:  6
# step:  31  average residual:  122.20608727784501  NumInliers:  3
# step:  31  average residual:  584.2478444683512  NumInliers:  3
# step:  31  average residual:  999.4609146170411  NumInliers:  16
# step:  31  average residual:  13.491488502106236  NumInliers:  19
# step:  31  average residual:  183538.05245439292  NumInliers:  4
# step:  31  average residual:  1919.0583997012104  NumInliers:  5
# step:  31  average residual:  43.93343239926823  NumInliers:  3
# step:  31  average residual:  10.285458560550639  NumInliers:  26
# step:  31  average residual:  162.58293936726247  NumInliers:  15
# step:  31  average residual:  88.38715570161384  NumInliers:  5
# step:  31  average residual:  11.747433782489303  NumInliers:  26
# step:  31  average residual:  11.236700417480158  NumInliers:  27
# step:  31  average residual:  108.9581303977787  NumInliers:  6
# step:  31  average residual:  81.21026779681334  NumInliers:  14
# step:  31  average residual:  67.22843058512123  NumInliers:  11
# step:  31  average residual:  95.12372255889755  NumInliers:  7
# step:  31  average residual:  55.87932199417682  NumInliers:  15
# step:  31  average residual:  14.124534853813048  NumInliers:  27
# step:  31  average residual:  23.57417503191856  NumInliers:  19
# step:  31  average residual:  232.61399158645384  NumInliers:  8
# step:  31  average residual:  86.41057665523903  NumInliers:  7
# step:  31  average residual:  35.84514048816786  NumInliers:  16
# step:  31  average residual:  125.13428495233111  NumInliers:  3
# step:  31  average residual:  185.3115371470649  NumInliers:  4
# step:  31  average residual:  12.329625911332851  NumInliers:  21
# step:  31  average residual:  11.198003013119674  NumInliers:  26
# step:  31  average residual:  34.94524000766096  NumInliers:  4
# step:  31  average residual:  11.852426159429594  NumInliers:  24
# step:  31  average residual:  115.87798266485639  NumInliers:  3
# step:  31  average residual:  1794.3509095427105  NumInliers:  4
# step:  31  average residual:  140.51699259754048  NumInliers:  21
# step:  31  average residual:  101.48286756364882  NumInliers:  4
# step:  31  average residual:  68.96826885015412  NumInliers:  6
# step:  31  average residual:  36.683400749313286  NumInliers:  18
# step:  31  average residual:  19.74754154939626  NumInliers:  26
# step:  31  average residual:  131.24322323084937  NumInliers:  10
# step:  31  average residual:  77.27205474477125  NumInliers:  9
# step:  31  average residual:  471.103572309812  NumInliers:  2
# step:  31  average residual:  87.80474355960857  NumInliers:  20
# step:  31  average residual:  755.4755946688335  NumInliers:  2
# step:  31  average residual:  64.29752673204524  NumInliers:  14
# step:  31  average residual:  62.76297320196623  NumInliers:  12
# step:  31  average residual:  1872.912499850698  NumInliers:  5
# step:  31  average residual:  161.95004830231522  NumInliers:  2
# step:  31  average residual:  76.72006372867999  NumInliers:  6
# step:  31  average residual:  101.98206767394355  NumInliers:  9
# step:  31  average residual:  605.2766968551836  NumInliers:  1
# step:  31  average residual:  162.3972022136652  NumInliers:  7
# step:  31  average residual:  60.95773360546718  NumInliers:  14
# step:  31  average residual:  238.36646734014755  NumInliers:  13
# step:  31  average residual:  10.587532908130061  NumInliers:  26
# step:  31  average residual:  111.70911358095073  NumInliers:  10
# step:  31  average residual:  199.14865993691527  NumInliers:  6
# step:  31  average residual:  55.33989026853817  NumInliers:  15
# step:  31  average residual:  58.077287948073845  NumInliers:  13
# step:  31  average residual:  170.3941554860241  NumInliers:  12
# step:  31  average residual:  282.1998410266432  NumInliers:  3
# step:  31  average residual:  163.52189346006685  NumInliers:  3
# step:  31  average residual:  735.8267824192959  NumInliers:  5
# step:  31  average residual:  66.17943093220246  NumInliers:  7
# step:  31  average residual:  579.8434538320856  NumInliers:  6
# step:  31  average residual:  294.17184452690896  NumInliers:  13
# step:  31  average residual:  133.07001083872012  NumInliers:  7
# step:  31  average residual:  150.72931168007688  NumInliers:  13
# step:  31  average residual:  115.06117113645392  NumInliers:  9
# step:  31  average residual:  505.2876076325366  NumInliers:  7
# step:  31  average residual:  10.37184251033189  NumInliers:  26
# step:  31  average residual:  19.827889433477775  NumInliers:  16
# step:  31  average residual:  78.40415477146361  NumInliers:  12
# step:  31  average residual:  27.245142164664472  NumInliers:  15
# step:  31  average residual:  140.8891218335888  NumInliers:  9
# step:  31  average residual:  397.4327768904211  NumInliers:  8
# step:  31  average residual:  85.2050023221515  NumInliers:  18
# step:  31  average residual:  75.66679134924777  NumInliers:  12
# step:  31  average residual:  72.09701940257492  NumInliers:  10
# step:  31  average residual:  990.4841857566003  NumInliers:  9
# step:  31  average residual:  51.197859355673096  NumInliers:  14
# step:  31  average residual:  87.59878831288415  NumInliers:  12
# step:  31  average residual:  275.9772938424872  NumInliers:  4
# step:  31  average residual:  23.631356183435464  NumInliers:  20
# step:  31  average residual:  21.74849441387815  NumInliers:  20
# step:  31  average residual:  12.265392134632704  NumInliers:  18
# step:  31  average residual:  69.17544715816867  NumInliers:  19
# step:  31  average residual:  189.26424749559646  NumInliers:  4
# step:  31  average residual:  156.14835012947628  NumInliers:  8
# step:  31  average residual:  37.823702317010984  NumInliers:  7
# step:  31  average residual:  60.92431016845497  NumInliers:  21
# step:  31  average residual:  17.771857179321522  NumInliers:  26
# step:  31  average residual:  734.7644750517438  NumInliers:  3
# step:  31  average residual:  10.193213738220717  NumInliers:  26
# step:  31  average residual:  14.456760956938163  NumInliers:  27
# step:  31  average residual:  601.0330989584244  NumInliers:  5
# step:  31  average residual:  143.99798256324277  NumInliers:  16
# step:  31  average residual:  146.12342100168644  NumInliers:  5
# step:  31  average residual:  109.36243135214173  NumInliers:  16
# step:  31  average residual:  316.3050799220906  NumInliers:  17
# step:  31  average residual:  66.62842163517377  NumInliers:  11
# step:  31  average residual:  23.00728042388088  NumInliers:  18
# step:  31  average residual:  56.16019806199769  NumInliers:  20
# step:  31  average residual:  23.20115923773914  NumInliers:  19
# step:  31  average residual:  133.4634340912421  NumInliers:  14
# step:  31  average residual:  45.65556414998288  NumInliers:  13
# step:  31  average residual:  83.8749480262955  NumInliers:  10
# step:  31  average residual:  28.148550186967444  NumInliers:  21
# step:  31  average residual:  370.6096567473369  NumInliers:  4
# step:  31  average residual:  74.68642422668408  NumInliers:  19
# step:  31  average residual:  11.669951232369309  NumInliers:  27
# step:  31  average residual:  50.412584033785556  NumInliers:  9
# step:  31  average residual:  606.7953774983185  NumInliers:  3
# step:  31  average residual:  399.7120024896307  NumInliers:  3
# step:  31  average residual:  11.740901374714923  NumInliers:  24
# step:  31  average residual:  12.180253116629391  NumInliers:  24
# step:  31  average residual:  223.58366380699687  NumInliers:  4
# step:  31  average residual:  122.63584829044207  NumInliers:  3
# step:  31  average residual:  339.523180336338  NumInliers:  3
# step:  31  average residual:  81.84745427100965  NumInliers:  10
# step:  31  average residual:  19.38842415581541  NumInliers:  22
# step:  31  average residual:  39.78207039566908  NumInliers:  18
# step:  31  average residual:  93.96517226240228  NumInliers:  6
# step:  31  average residual:  74.27810732425867  NumInliers:  13
# step:  31  average residual:  48.29481561374453  NumInliers:  15
# step:  31  average residual:  137.30707645476625  NumInliers:  8
# step:  31  average residual:  12.805056431322376  NumInliers:  24
# step:  31  average residual:  116.03668823682075  NumInliers:  12
# step:  31  average residual:  37.11882338616158  NumInliers:  14
# step:  31  average residual:  159.65510143810903  NumInliers:  8
# step:  31  average residual:  62.51925424677093  NumInliers:  16
# step:  31  average residual:  60.94495196892875  NumInliers:  13
# step:  31  average residual:  75.7840580978102  NumInliers:  7
# step:  31  average residual:  114.90466649825244  NumInliers:  10
# step:  31  average residual:  15.338052011424958  NumInliers:  27
# step:  31  average residual:  97.6251452529515  NumInliers:  9
# step:  31  average residual:  701.6042472455835  NumInliers:  6
# step:  31  average residual:  51.7896238739741  NumInliers:  7
# step:  31  average residual:  167.15684184910586  NumInliers:  18
# step:  31  average residual:  444.1969632779127  NumInliers:  4
# step:  31  average residual:  72.7855622560012  NumInliers:  5
# step:  31  average residual:  120.39150053130211  NumInliers:  5
# step:  31  average residual:  74.37361378604554  NumInliers:  15
# step:  31  average residual:  105.11912160978034  NumInliers:  4
# step:  31  average residual:  20.043883023176083  NumInliers:  20
# step:  31  average residual:  346.6341314276905  NumInliers:  8
# step:  31  average residual:  96.60541284607241  NumInliers:  10
# step:  31  average residual:  184.91071614872274  NumInliers:  3
# step:  31  average residual:  195.9718507734309  NumInliers:  7
# step:  31  average residual:  12.626598476388388  NumInliers:  27
# step:  31  average residual:  87.82905844285116  NumInliers:  5
# step:  31  average residual:  403.8076735610276  NumInliers:  2
# step:  31  average residual:  11.90729659433213  NumInliers:  23
# step:  31  average residual:  168.01536594398397  NumInliers:  13
# step:  31  average residual:  578.6787854458174  NumInliers:  3
# step:  31  average residual:  106.06103212857019  NumInliers:  12
# step:  31  average residual:  205.25557248809633  NumInliers:  17
# step:  31  average residual:  242.43313452031907  NumInliers:  4
# step:  31  average residual:  374.1417310300981  NumInliers:  10
# step:  31  average residual:  119.55773589491837  NumInliers:  13
# step:  31  average residual:  317.22996197857873  NumInliers:  15
# step:  31  average residual:  246.15136163021995  NumInliers:  7
# step:  31  average residual:  104.87792035383683  NumInliers:  6
# step:  31  average residual:  998.9993921749526  NumInliers:  13
# step:  31  average residual:  154.48870816434578  NumInliers:  4
# step:  31  average residual:  16.918075411118586  NumInliers:  22
# step:  31  average residual:  30.060025467072933  NumInliers:  22
# step:  31  average residual:  12.842477533720064  NumInliers:  27
# step:  31  average residual:  148.96305998744896  NumInliers:  16
# step:  31  average residual:  81.57014272483575  NumInliers:  5
# step:  31  average residual:  144.21142636061552  NumInliers:  3
# step:  31  average residual:  1325.6466865323391  NumInliers:  5
# step:  31  average residual:  212.48939652897866  NumInliers:  3
# step:  31  average residual:  878.4212778206304  NumInliers:  5
# step:  31  average residual:  145.21161459712118  NumInliers:  3
# step:  31  average residual:  112.7410715013258  NumInliers:  10
# step:  31  average residual:  14.348339309611456  NumInliers:  27
# step:  31  average residual:  250.39936239053085  NumInliers:  23
# step:  31  average residual:  32.67728681988389  NumInliers:  14
# step:  31  average residual:  18.191772145181666  NumInliers:  16
# step:  31  average residual:  2274.373286277704  NumInliers:  2
# step:  31  average residual:  234.5701722431738  NumInliers:  3
# step:  31  average residual:  84.99435637838286  NumInliers:  22
# step:  31  average residual:  339.58985999285693  NumInliers:  2
# step:  31  average residual:  115.20274257608295  NumInliers:  10
# step:  31  average residual:  173.3181620058837  NumInliers:  3
# step:  31  average residual:  74.94614466787104  NumInliers:  11
# step:  31  average residual:  197.16484845217235  NumInliers:  2
# step:  31  average residual:  26.09422589333413  NumInliers:  11
# step:  31  average residual:  273.7925205273451  NumInliers:  2
# step:  31  average residual:  11.402641221063757  NumInliers:  24
# step:  31  average residual:  479.2148782301093  NumInliers:  15
# step:  31  average residual:  116.66572510121986  NumInliers:  10
# step:  31  average residual:  115.69645780269144  NumInliers:  9
# step:  31  average residual:  293.1125177469839  NumInliers:  16
# step:  31  average residual:  51.141972648812214  NumInliers:  18
# step:  31  average residual:  72.1705328846447  NumInliers:  7
# step:  31  average residual:  15.37961611028592  NumInliers:  21
# step:  31  average residual:  243.14237658819542  NumInliers:  4
# step:  31  average residual:  15.245875884683453  NumInliers:  16
# step:  31  average residual:  29.97804468533221  NumInliers:  25
# step:  31  average residual:  72.74880323735148  NumInliers:  10
# step:  31  average residual:  74.38884505500259  NumInliers:  17
# step:  31  average residual:  132.92644944247883  NumInliers:  10
# step:  31  average residual:  87.92673115037108  NumInliers:  15
# step:  31  average residual:  83.64538987157735  NumInliers:  6
# step:  31  average residual:  370.6450057720751  NumInliers:  9
# step:  31  average residual:  51.31736702516665  NumInliers:  25
# step:  31  average residual:  71.42621919138341  NumInliers:  14
# step:  31  average residual:  692.2601752128719  NumInliers:  3
# step:  31  average residual:  269.9850754358532  NumInliers:  8
# step:  31  average residual:  273.30136322980394  NumInliers:  16
# step:  31  average residual:  51.86033290665647  NumInliers:  13
# step:  31  average residual:  65.40174390366357  NumInliers:  14
# step:  31  average residual:  111.72038392719796  NumInliers:  10
# step:  31  average residual:  14.579676545693845  NumInliers:  27
# step:  31  average residual:  143.61390943320825  NumInliers:  4
# step:  31  average residual:  76.2319664414637  NumInliers:  10
# step:  31  average residual:  13.316906946597742  NumInliers:  27
# step:  31  average residual:  20.758540621904476  NumInliers:  24
# step:  31  average residual:  16.501970222389957  NumInliers:  18
# step:  31  average residual:  106.61279455183274  NumInliers:  19
# step:  31  average residual:  143.26062836630553  NumInliers:  16
# step:  31  average residual:  62.67180535351497  NumInliers:  10
# step:  31  average residual:  121.21779055767416  NumInliers:  3
# step:  31  average residual:  114.02543781284677  NumInliers:  10
# step:  31  average residual:  296.985682555409  NumInliers:  5
# step:  31  average residual:  275.55914986636816  NumInliers:  7
# step:  31  average residual:  60.64100974888348  NumInliers:  5
# step:  31  average residual:  156.8268977433485  NumInliers:  8
# step:  31  average residual:  99.33178096184409  NumInliers:  4
# step:  31  average residual:  456.5481493096551  NumInliers:  2
# step:  31  average residual:  195.55064026095204  NumInliers:  5
# step:  31  average residual:  218.66758088619827  NumInliers:  15
# step:  31  average residual:  16.24514524309354  NumInliers:  22
# step:  31  average residual:  11.284318521407938  NumInliers:  25
# step:  31  average residual:  63.58470141224401  NumInliers:  14
# step:  31  average residual:  54.051746271958734  NumInliers:  18
# step:  31  average residual:  236.1653833607509  NumInliers:  15
# step:  31  average residual:  136.46128598759492  NumInliers:  9
# step:  31  average residual:  570.3362818665101  NumInliers:  1
# step:  31  average residual:  55.06332830655411  NumInliers:  14
# step:  31  average residual:  15.798811369734509  NumInliers:  26
# step:  31  average residual:  140.2178846942052  NumInliers:  7
# step:  31  average residual:  167.85390841190565  NumInliers:  3
# step:  31  average residual:  108.16062109819013  NumInliers:  7
# step:  31  average residual:  628.7330574435366  NumInliers:  0
# step:  31  average residual:  72.85264692412244  NumInliers:  12
# step:  31  average residual:  517.8045244003827  NumInliers:  4
# step:  31  average residual:  102.88902605417748  NumInliers:  10
# step:  31  average residual:  132.55805404671045  NumInliers:  12
# step:  31  average residual:  76.07014626952882  NumInliers:  8
# step:  31  average residual:  67.13505767713511  NumInliers:  11
# step:  31  average residual:  12.676270733575555  NumInliers:  27
# step:  31  average residual:  11.202434301330861  NumInliers:  25
# step:  31  average residual:  18.747845875286142  NumInliers:  18
# step:  31  average residual:  88.45449786940135  NumInliers:  16
# step:  31  average residual:  14.759226862457083  NumInliers:  27
# step:  31  average residual:  604.3685068979817  NumInliers:  2
# step:  31  average residual:  289.13765923455037  NumInliers:  4
# step:  31  average residual:  15.88651315152628  NumInliers:  23
# step:  31  average residual:  146.8422112488246  NumInliers:  9
# step:  31  average residual:  24.065135217312573  NumInliers:  15
# step:  31  average residual:  322.9171410619697  NumInliers:  17
# step:  31  average residual:  151.92506783905034  NumInliers:  7
# step:  31  average residual:  138.32561708011167  NumInliers:  5
# step:  31  average residual:  11.774236014639401  NumInliers:  24
# step:  31  average residual:  96.34604711791238  NumInliers:  13
# step:  31  average residual:  114.46147689036486  NumInliers:  10
# step:  31  average residual:  63.27529284997307  NumInliers:  12
# step:  31  average residual:  95.17279679979173  NumInliers:  11
# step:  31  average residual:  47.822593346322265  NumInliers:  14
# step:  31  average residual:  14.841565812094895  NumInliers:  27
# step:  31  average residual:  14.224776525512937  NumInliers:  27
# step:  31  average residual:  20.58927554995732  NumInliers:  18
# step:  31  average residual:  17.116241839388753  NumInliers:  27
# step:  31  average residual:  145.21415956397774  NumInliers:  12
# step:  31  average residual:  104.8963133984138  NumInliers:  7
# step:  31  average residual:  103.56882062714632  NumInliers:  6
# step:  31  average residual:  206.12265571065456  NumInliers:  2
# step:  31  average residual:  22.01915776114084  NumInliers:  17
# step:  31  average residual:  613.838080062614  NumInliers:  16
# step:  31  average residual:  16.677681184809728  NumInliers:  27
# step:  31  average residual:  139.58023670703088  NumInliers:  4
# step:  31  average residual:  99.6363804244289  NumInliers:  8
# step:  31  average residual:  181.10917677988357  NumInliers:  6
# step:  31  average residual:  665.3213772055936  NumInliers:  1
# step:  31  average residual:  71.44049523994646  NumInliers:  7
# step:  31  average residual:  218.9732774139601  NumInliers:  5
# step:  31  average residual:  12.210311441057563  NumInliers:  27
# step:  31  average residual:  11.042811538500224  NumInliers:  25
# step:  31  average residual:  92.79922068517497  NumInliers:  12
# step:  31  average residual:  16.094747798898844  NumInliers:  20
# step:  31  average residual:  20.06631473685275  NumInliers:  18
# step:  31  average residual:  60.31200559674174  NumInliers:  12
# step:  31  average residual:  156.1721419397912  NumInliers:  3
# step:  31  average residual:  281.67125241795645  NumInliers:  16
# step:  31  average residual:  72.60300674069035  NumInliers:  14
# step:  31  average residual:  111.3482567620129  NumInliers:  10
# step:  31  average residual:  107.73904244398352  NumInliers:  6
# step:  31  average residual:  62.178326222608554  NumInliers:  18
# step:  31  average residual:  196.51513364267785  NumInliers:  3
# step:  31  average residual:  62.18482792512829  NumInliers:  13
# step:  31  average residual:  116.6487930535834  NumInliers:  3
# step:  31  average residual:  84.39171570230853  NumInliers:  9
# step:  31  average residual:  88.07498528163175  NumInliers:  12
# step:  31  average residual:  126.06708246602527  NumInliers:  8
# step:  31  average residual:  110.37632732255969  NumInliers:  10
# step:  31  average residual:  83.02651229862687  NumInliers:  14
# step:  31  average residual:  119.4689124999537  NumInliers:  10
# step:  31  average residual:  14.557520540945484  NumInliers:  23
# step:  31  average residual:  90.61622183525269  NumInliers:  10
# step:  31  average residual:  106.63855784080481  NumInliers:  12
# step:  31  average residual:  56.6422649760195  NumInliers:  20
# step:  31  average residual:  242.3454497191939  NumInliers:  3
# step:  31  average residual:  159.09461988586727  NumInliers:  18
# step:  31  average residual:  158.20643756028832  NumInliers:  4
# step:  31  average residual:  66.15182414721448  NumInliers:  13
# step:  31  average residual:  69.68426377862465  NumInliers:  16
# step:  31  average residual:  809.4929847857744  NumInliers:  3
# step:  31  average residual:  518.1818335048315  NumInliers:  8
# step:  31  average residual:  13.234457146717277  NumInliers:  27
# step:  31  average residual:  118.19031463173167  NumInliers:  7
# step:  31  average residual:  284.6370549049543  NumInliers:  8
# step:  31  average residual:  59.06086761916346  NumInliers:  15
# step:  31  average residual:  113.33280804443534  NumInliers:  8
# step:  31  average residual:  105.68967893869568  NumInliers:  3
# step:  31  average residual:  105.65336297461569  NumInliers:  10
# step:  31  average residual:  93.50812323322566  NumInliers:  13
# step:  31  average residual:  17.7028549367698  NumInliers:  19
# step:  31  average residual:  24.34645855664246  NumInliers:  25
# step:  31  average residual:  75.07783948521278  NumInliers:  7
# step:  31  average residual:  87.33339544139443  NumInliers:  13
# step:  31  average residual:  78.82741024798109  NumInliers:  13
# step:  31  average residual:  173.8125153590696  NumInliers:  13
# step:  31  average residual:  28.72321323335052  NumInliers:  15
# step:  31  average residual:  208.906719145683  NumInliers:  13
# ...
# step:  31  average residual:  25.187526943174824  NumInliers:  18
# step:  31  average residual:  532.9588084355505  NumInliers:  2
# step:  31  average residual:  15.862661893492916  NumInliers:  18
# step:  31  average residual:  67.78805469354099  NumInliers:  13
# step:  31  average residual:  62.84858215597438  NumInliers:  10
# step:  31  average residual:  114.62156442442996  NumInliers:  7
# step:  31  average residual:  308.86156250418196  NumInliers:  3
# step:  31  average residual:  310.15274117456636  NumInliers:  16
# step:  31  average residual:  24.780089920782892  NumInliers:  14
# step:  31  average residual:  11.456781355579205  NumInliers:  24
# step:  31  average residual:  122.4508378122089  NumInliers:  17
# step:  31  average residual:  161.46529846920765  NumInliers:  6
# step:  31  average residual:  72.41864256531484  NumInliers:  5
# step:  31  average residual:  159.09983771173526  NumInliers:  7
# step:  31  average residual:  388.95833683941316  NumInliers:  3
# step:  31  average residual:  140.31165874698294  NumInliers:  8
# step:  31  average residual:  126.12531413120408  NumInliers:  12
# step:  31  average residual:  22.918369562429433  NumInliers:  18
# step:  31  average residual:  320.4903084073829  NumInliers:  6
# step:  31  average residual:  258.8353701178938  NumInliers:  4
# step:  31  average residual:  65.40093526360334  NumInliers:  10
# step:  31  average residual:  172.9868386671118  NumInliers:  5
# step:  31  average residual:  646.9322450982611  NumInliers:  1
# step:  31  average residual:  18.25016076737457  NumInliers:  17
# step:  31  average residual:  193.3323004691562  NumInliers:  3
# step:  31  average residual:  21.052793689810546  NumInliers:  17
# step:  31  average residual:  160.7207701023399  NumInliers:  16
# step:  31  average residual:  48.27662733468335  NumInliers:  5
# step:  31  average residual:  106.68852219035824  NumInliers:  9
# step:  31  average residual:  178.80361795841577  NumInliers:  7
# step:  31  average residual:  644.9049054158594  NumInliers:  1
# step:  31  average residual:  613.0967667765685  NumInliers:  1
# step:  31  average residual:  85.44099943447893  NumInliers:  13
# step:  31  average residual:  23.415267206181134  NumInliers:  18
# step:  31  average residual:  71.14091646931756  NumInliers:  8
# step:  31  average residual:  103.56882061386162  NumInliers:  6
# step:  31  average residual:  262.1714505200507  NumInliers:  4
# step:  31  average residual:  113.13418504818861  NumInliers:  10
# step:  31  average residual:  51.30793388648071  NumInliers:  13
# step:  31  average residual:  87.1861594374549  NumInliers:  10
# step:  31  average residual:  242.52424678348797  NumInliers:  7
# step:  31  average residual:  60.84440647424581  NumInliers:  17
# step:  31  average residual:  248.8665995368612  NumInliers:  8
# step:  31  average residual:  97.45209244265338  NumInliers:  15
# step:  31  average residual:  106.15096542937685  NumInliers:  12
# step:  31  average residual:  2772.9001731023563  NumInliers:  3
# step:  31  average residual:  37.25967835079079  NumInliers:  18
# step:  31  average residual:  128.22961253677138  NumInliers:  5
# step:  31  average residual:  128.6064921742148  NumInliers:  10
# step:  31  average residual:  86.62834242317264  NumInliers:  17
# step:  31  average residual:  113.88025621986982  NumInliers:  18
# step:  31  average residual:  121.31052656958371  NumInliers:  8
# step:  31  average residual:  13.933408288373139  NumInliers:  27
# step:  31  average residual:  2182.1832001147545  NumInliers:  7
# step:  31  average residual:  112.98590967405082  NumInliers:  14
# step:  31  average residual:  45.452360786953  NumInliers:  16
# step:  31  average residual:  114.20723017100609  NumInliers:  5
# step:  31  average residual:  79.42968797786784  NumInliers:  7
# step:  31  average residual:  98.86110260020723  NumInliers:  10
# step:  31  average residual:  131.59072149509947  NumInliers:  10
# step:  31  average residual:  74.33041152754808  NumInliers:  12
# step:  31  average residual:  185.79104917225465  NumInliers:  6
# step:  31  average residual:  114.16644897865177  NumInliers:  7
# step:  31  average residual:  10.987354186029014  NumInliers:  27
# step:  31  average residual:  94.40341020000422  NumInliers:  16
# step:  31  average residual:  16.15064007536533  NumInliers:  27
# step:  31  average residual:  260.7556486756601  NumInliers:  8
# step:  31  average residual:  64.11305412495982  NumInliers:  9
# step:  31  average residual:  108.1606211258043  NumInliers:  7
# step:  31  average residual:  16.326407827081496  NumInliers:  19
# step:  31  average residual:  82.90206125794963  NumInliers:  10
# step:  31  average residual:  83.89721329046183  NumInliers:  8
# step:  31  average residual:  148.9099644643714  NumInliers:  10
# step:  31  average residual:  15.11907865292563  NumInliers:  21
# step:  31  average residual:  81.6589519811465  NumInliers:  12
# step:  31  average residual:  14.979266622141738  NumInliers:  27
# step:  31  average residual:  135.31656711307105  NumInliers:  12
# step:  31  average residual:  111.11800149308922  NumInliers:  10
# step:  31  average residual:  874.4254539603744  NumInliers:  18
# step:  31  average residual:  139.70272076632338  NumInliers:  6
# step:  31  average residual:  180.48564436364813  NumInliers:  3
# step:  31  average residual:  114.48094692553313  NumInliers:  3
# step:  31  average residual:  228.74371540420512  NumInliers:  10
# step:  31  average residual:  32.76047946090006  NumInliers:  5
# step:  31  average residual:  20.44971261319075  NumInliers:  26
# step:  31  average residual:  68.22208315161477  NumInliers:  10
# step:  31  average residual:  634.9412690395244  NumInliers:  2
# step:  31  average residual:  95.6738525110471  NumInliers:  18
# step:  31  average residual:  171.14323697173614  NumInliers:  7
# step:  31  average residual:  16.881857981589672  NumInliers:  22
# step:  31  average residual:  112.6598577786244  NumInliers:  8
# step:  31  average residual:  15.095755822706026  NumInliers:  26
# step:  31  average residual:  78.23650041380596  NumInliers:  15
# step:  31  average residual:  95.8921813732437  NumInliers:  8
# step:  31  average residual:  79.461319934139  NumInliers:  8
# step:  31  average residual:  629.7765690700645  NumInliers:  3
# step:  31  average residual:  15.116339605439599  NumInliers:  26
# step:  31  average residual:  169.77539045284504  NumInliers:  5
# step:  31  average residual:  123.44388603024012  NumInliers:  17
# step:  31  average residual:  13.20248557771111  NumInliers:  24
# step:  31  average residual:  79.09133840790967  NumInliers:  11
# step:  31  average residual:  188.70519213485838  NumInliers:  3
# step:  31  average residual:  653.6489309092148  NumInliers:  1
# step:  31  average residual:  74.77621823984973  NumInliers:  12
# step:  31  average residual:  72.3761513482975  NumInliers:  11
# step:  31  average residual:  63.592070820376506  NumInliers:  14
# step:  31  average residual:  17.707224754253332  NumInliers:  18
# step:  31  average residual:  140.27640465557474  NumInliers:  7
# step:  31  average residual:  71.54077261755214  NumInliers:  6
# step:  31  average residual:  196.057281734961  NumInliers:  2
# step:  31  average residual:  116.12434132279157  NumInliers:  13
# step:  31  average residual:  23.96213515660432  NumInliers:  14
# step:  31  average residual:  50.5853586287259  NumInliers:  5
# step:  31  average residual:  57.96501668841315  NumInliers:  19
# step:  31  average residual:  73.07168666678602  NumInliers:  17
# step:  31  average residual:  74.3722586745318  NumInliers:  8
# step:  31  average residual:  92.60149601271182  NumInliers:  18
# step:  31  average residual:  63.86377586019503  NumInliers:  13
# step:  31  average residual:  646.1869134853144  NumInliers:  4
# step:  31  average residual:  87.89016524444662  NumInliers:  14
# step:  31  average residual:  95.0298122078053  NumInliers:  13
# step:  31  average residual:  72.40800278404231  NumInliers:  20
# step:  31  average residual:  404.90412241041616  NumInliers:  4
# step:  31  average residual:  567.6548531130508  NumInliers:  3
# step:  31  average residual:  594.8180045590549  NumInliers:  0
# step:  31  average residual:  14.691497769874898  NumInliers:  18
# step:  31  average residual:  66.18118993775757  NumInliers:  17
# step:  31  average residual:  13.209001420699629  NumInliers:  27
# step:  31  average residual:  16.2916937390503  NumInliers:  18
# step:  31  average residual:  671.9417112072166  NumInliers:  1
# step:  31  average residual:  118.23724132100983  NumInliers:  3
# step:  31  average residual:  158.695362137644  NumInliers:  4
# step:  31  average residual:  87.06816541327794  NumInliers:  18
# step:  31  average residual:  146.65089502396154  NumInliers:  4
# step:  31  average residual:  12.27995100506286  NumInliers:  27
# step:  31  average residual:  95.31505897072412  NumInliers:  13
# step:  31  average residual:  174.27300879392348  NumInliers:  5
# step:  31  average residual:  10.419586418853731  NumInliers:  26
# step:  31  average residual:  65.10024157376822  NumInliers:  20
# step:  31  average residual:  10.98631953844309  NumInliers:  25
# step:  31  average residual:  302.6656608381447  NumInliers:  5
# step:  31  average residual:  14.430479334362884  NumInliers:  27
# step:  31  average residual:  16.985980218524105  NumInliers:  26
# step:  31  average residual:  345.1607147469172  NumInliers:  16
# step:  31  average residual:  101.17589120190138  NumInliers:  7
# step:  31  average residual:  47.749011224736115  NumInliers:  6
# step:  31  average residual:  12.417474368745525  NumInliers:  27
# step:  31  average residual:  27.196677249261526  NumInliers:  15
# step:  31  average residual:  138.13349052528017  NumInliers:  12
# step:  31  average residual:  13.65871277591053  NumInliers:  19
# step:  31  average residual:  244.10636199228662  NumInliers:  16
# step:  31  average residual:  450.04737106323233  NumInliers:  2
# step:  31  average residual:  125.53895726049427  NumInliers:  18
# step:  31  average residual:  13.969040911335778  NumInliers:  21
# step:  31  average residual:  302.0328851052853  NumInliers:  8
# step:  31  average residual:  65.95383854195897  NumInliers:  17
# step:  31  average residual:  53.77876862542645  NumInliers:  5
# step:  31  average residual:  110.96690395306523  NumInliers:  10
# step:  31  average residual:  80.2794594982593  NumInliers:  4
# step:  31  average residual:  167.2491775495899  NumInliers:  2
# step:  31  average residual:  64.27384622497274  NumInliers:  10
# step:  31  average residual:  186.904367168536  NumInliers:  5
# step:  31  average residual:  13.537016414471305  NumInliers:  27
# step:  31  average residual:  71.6024946319327  NumInliers:  12
# step:  31  average residual:  121.42684970999235  NumInliers:  14
# step:  31  average residual:  96.9369050271579  NumInliers:  7
# step:  31  average residual:  107.59746119090191  NumInliers:  5
# step:  31  average residual:  86.59810331867851  NumInliers:  7
# step:  31  average residual:  90.40957320904748  NumInliers:  4
# step:  31  average residual:  87.02804342671952  NumInliers:  7
# step:  31  average residual:  42.05698125347032  NumInliers:  15
# step:  31  average residual:  161.22145780268445  NumInliers:  3
# step:  31  average residual:  327.5469983823378  NumInliers:  11
# step:  31  average residual:  74.81919130268344  NumInliers:  19
# step:  31  average residual:  68.4165843639766  NumInliers:  18
# step:  31  average residual:  272.8416031898507  NumInliers:  2
# step:  31  average residual:  167.10411496846046  NumInliers:  3
# step:  31  average residual:  229.41723932582894  NumInliers:  9
# step:  31  average residual:  386.7716991458089  NumInliers:  4
# step:  31  average residual:  20.165023686799003  NumInliers:  26
# step:  31  average residual:  124.12309650841523  NumInliers:  5
# step:  31  average residual:  389.60776971912236  NumInliers:  3
# step:  31  average residual:  27.606149864089456  NumInliers:  17
# step:  31  average residual:  13.251121903414772  NumInliers:  24
# step:  31  average residual:  105.5286995115576  NumInliers:  10
# step:  31  average residual:  68.34852305030249  NumInliers:  8
# step:  31  average residual:  73.18753563634054  NumInliers:  14
# step:  31  average residual:  10.785901883366769  NumInliers:  24
# step:  31  average residual:  14.952558377934691  NumInliers:  27
# step:  31  average residual:  52.5485561006809  NumInliers:  13
# step:  31  average residual:  68.34665136693854  NumInliers:  14
# step:  31  average residual:  124.72661809886614  NumInliers:  3
# step:  31  average residual:  635.965712120083  NumInliers:  5
# step:  31  average residual:  92.58909165665723  NumInliers:  14
# step:  31  average residual:  989.8397852991213  NumInliers:  4
# step:  31  average residual:  148.3434050365809  NumInliers:  6
# step:  31  average residual:  99.90484736999178  NumInliers:  3
# step:  31  average residual:  170.75639040788593  NumInliers:  4
# step:  31  average residual:  73.7385843746249  NumInliers:  10
# step:  31  average residual:  200.63534326278224  NumInliers:  7
# step:  31  average residual:  53.84289025473406  NumInliers:  7
# step:  31  average residual:  69.65168485000538  NumInliers:  7
# step:  31  average residual:  180.06744807797318  NumInliers:  6
# step:  31  average residual:  5006.991656143789  NumInliers:  3
# step:  31  average residual:  81.29881055837262  NumInliers:  10
# step:  31  average residual:  112.38400175592258  NumInliers:  10
# step:  31  average residual:  115.7920013619985  NumInliers:  9
# step:  31  average residual:  51.671102207009476  NumInliers:  17
# step:  31  average residual:  64.6402493948705  NumInliers:  10
# step:  31  average residual:  604.3428074658068  NumInliers:  2
# step:  31  average residual:  62.794356028212505  NumInliers:  17
# step:  31  average residual:  77.9129036816758  NumInliers:  7
# step:  31  average residual:  135.87545007335336  NumInliers:  8
# step:  31  average residual:  83.59697380026023  NumInliers:  18
# step:  31  average residual:  12.669577480555873  NumInliers:  27
# step:  31  average residual:  11.091032758378084  NumInliers:  27
# step:  31  average residual:  576.0638308056492  NumInliers:  7
# step:  31  average residual:  648.5747161409479  NumInliers:  1
# step:  31  average residual:  36.67910117694135  NumInliers:  20
# step:  31  average residual:  15.922947439469132  NumInliers:  23
# step:  31  average residual:  19.34354732764365  NumInliers:  15
# step:  31  average residual:  31.26688736159949  NumInliers:  24
# step:  31  average residual:  72.26436138025342  NumInliers:  12
# step:  31  average residual:  74.28631023938414  NumInliers:  8
# step:  31  average residual:  24.740667252528596  NumInliers:  17
# step:  31  average residual:  93.15364877178789  NumInliers:  11
# step:  31  average residual:  15.179108430442819  NumInliers:  27
# step:  31  average residual:  107.74336387426844  NumInliers:  5
# step:  31  average residual:  122.95045738519656  NumInliers:  7
# step:  31  average residual:  26.86692283670314  NumInliers:  18
# step:  31  average residual:  314.3150435763993  NumInliers:  7
# step:  31  average residual:  136.19066973149137  NumInliers:  6
# step:  31  average residual:  51.897303946940106  NumInliers:  17
# step:  31  average residual:  88.90694296022843  NumInliers:  11
# step:  31  average residual:  361.8056920949012  NumInliers:  7
# step:  31  average residual:  162.80642128219682  NumInliers:  14
# step:  31  average residual:  117.14849535867775  NumInliers:  10
# step:  31  average residual:  29.3396504560312  NumInliers:  14
# step:  31  average residual:  14.705965903448773  NumInliers:  26
# step:  31  average residual:  114.6215653137916  NumInliers:  7
# step:  31  average residual:  964.5471035389068  NumInliers:  7
# step:  31  average residual:  118.55332904104027  NumInliers:  9
# step:  31  average residual:  383.5701677856449  NumInliers:  5
# step:  31  average residual:  158.78068297720677  NumInliers:  3
# step:  31  average residual:  65.78456558080077  NumInliers:  14
# step:  31  average residual:  74.28103013066807  NumInliers:  7

# %%
len(inliers)
# Out:
# 27

# %%
inliers = np.array(inliers).reshape(-1, 4)

# %%
plt.show()
fig = plt.figure()
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)
ax1.imshow(images[2], cmap='gray')
ax2.imshow(images[3], cmap='gray')
for x1, y1, x2, y2 in zip(inliers[:, 0], inliers[:, 1], inliers[:, 2], inliers[:, 3]):
    ax1.scatter(x1, y1, marker='x')
    ax2.scatter(x2, y2, marker='x')
ax1.axis('off')
ax2.axis('off')
plt.show()

# %%
finalH
# Out:
# matrix([[-5.69416041e-01,  6.78409415e-01,  2.03780806e+02],
#         [-1.08869292e+00,  7.49439461e-01,  5.17000000e+02],
#         [-2.10578902e-03,  1.44959277e-03,  1.00000000e+00]])

# %%
height, width = images[2].shape
dst = cv2.warpPerspective(images[2],finalH,(width, height))
plt.subplot(122)
plt.imshow(dst,cmap='gray')
plt.title('Warped Imag')
plt.show()
plt.figure()
dst[0:images[2].shape[0], 0:images[2].shape[1]] = images[2]
#cv2.imwrite(‘output.jpg’,dst)
plt.imshow(dst,cmap='gray')
plt.show()
